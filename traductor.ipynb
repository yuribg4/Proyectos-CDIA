# %%
dic = {
    "hola": "hello",
    "adios": "goodbye",
    "gracias": "thank you",
    "por favor": "please",
    "perro": "dog",
    "gato": "cat",
    "casa": "house",
    "comida": "food",
    "agua": "water",
    "libro": "book",
    "escuela": "school",
    "amigo": "friend",
    "familia": "family",
    "trabajo": "work",
    "dinero": "money",
    "tiempo": "time",
    "día": "day",
    "noche": "night",
    "ciudad": "city",
    "camino": "road"
}

def translate(word):
    return dic.get(word, "no existe")

word = input("Ingresa una palabra: ")
print(translate(word))
# Out:
# Ingresa una palabra: hola
# hello
